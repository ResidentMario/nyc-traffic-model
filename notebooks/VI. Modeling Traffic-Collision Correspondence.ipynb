# %% [markdown]
# # VI. Modeling Traffic-Collision Correspondence
#
# Now for the moment of truth, is this data actually something we can accurately model?

# %%
import geopandas as gpd
data = gpd.read_file("../data/interm/aadt_mvc_combined.geojson")

# %%
data.head()
# Out:
#     AADT AADT_TYPE AADT_YEAR   AMVC_END  AMVC_START  BMP         BegDesc  \
# 0   7847  FORECAST      2014   6.597805    6.833441  0.0      JEROME AVE
# 1   5383  FORECAST      2014   0.471272   35.345384  0.0   E TREMONT AVE
# 2  21308  FORECAST      2014   0.235636   31.103938  2.6  WHITE PLAINS R
# 3  15699  FORECAST      2014  25.684312   34.874112  0.4       BOSTON RD
# 4   8344  FORECAST      2014   7.304713   14.373790  0.6     METCALF AVE
#
#    END_ERROR    EP         EndDesc  \
# 0   2.820690  1.09  UNIVERSITY AVE
# 1   0.773816  1.23  E KINGSBRDG RD
# 2  21.152265  3.48       SILVER ST
# 3   2.465165  0.92      E 233RD ST
# 4   3.742979  1.42     PUGSLEY AVE
#
#                          ...                                   MUNI  \
# 0                        ...                          City of Bronx
# 1                        ...                          City of Bronx
# 2                        ...                          City of Bronx
# 3                        ...                          City of Bronx
# 4                        ...                          City of Bronx
#
#    MVC_END_X  MVC_END_Y  MVC_START_X  MVC_START_Y    RC_ID  ROADWAYTYP  \
# 0 -73.923623  40.844237   -73.931225    40.829478  01_2030        Road
# 1 -73.894025  40.864892   -73.901022    40.847667  01_2024        Road
# 2 -73.848478  40.843024   -73.864478    40.841087  01_1167        Road
# 3 -73.841962  40.888456   -73.838742    40.881266  01_1106        Road
# 4 -73.855649  40.824632   -73.871002    40.822562  01_2043        Road
#
#   START_ERROR   Shape_Leng                                           geometry
# 0   24.951617  1744.861678  LINESTRING Z (-73.93109203821405 40.8296789857...
# 1   60.139634  1981.682023  LINESTRING Z (-73.90146605153026 40.8480909803...
# 2   27.291144  1415.639161  LINESTRING Z (-73.86477260758522 40.8409845678...
# 3    5.197127   836.201775  LINESTRING Z (-73.83876496360224 40.8813099830...
# 4    2.338001  1316.331740  LINESTRING Z (-73.87097401539016 40.8225599646...
#
# [5 rows x 22 columns]
